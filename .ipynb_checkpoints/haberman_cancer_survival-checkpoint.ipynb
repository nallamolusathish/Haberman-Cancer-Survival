# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
cancer=pd.read_csv('haberman.csv')
print(cancer.shape)
print(cancer.columns)
print(cancer.head(5))
# Out:
# (305, 4)
# Index(['age', 'year', 'nodes', 'status'], dtype='object')
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %% [markdown]
# # observations
#
# 1. there are 4 columns named ['age', 'year', 'nodes', 'status']
#
# 2. age,year,nodes are independent variables. status is dependent(class) variable.
#
# age: age of the patient at the time of opeartion
#
# year: year of operation
#
# nodes: number of positive axillary nodes detected
#
# status: survival status
# 1->lived more than 5 years after operation
#
# 2->lived less than 5 years after operation

# %%
cancer['status'].value_counts()       #
# Out:
# 1    225
# 2     80
# Name: status, dtype: int64

# %%
x,y='age','year'
cancer.plot(x,y,kind='scatter')
plt.show()

# %% [markdown]
# # observations
#
# this dataset is imbalanced. status=1 has 225 and status=2 has 80 values only.
#
# from the above grpah,we cant clearly visualize what is happening.we dont know what are the variables that are involved in the calculation of result.
#
# so,we have to pairplots to find the best variables for our model

# %%
sns.set_style('whitegrid')
sns.pairplot(cancer,hue='status',size=4)

# %% [markdown]
# this is imbalanced data set.

# %%
#we seperated status=1 and status=2 for our analysis

status1=cancer.loc[cancer['status']==1]
print(status1)
status2=cancer.loc[cancer['status']==2]
print(status2)
# Out:
#      age  year  nodes  status
# 0     30    64      1       1
# 1     30    62      3       1
# 2     30    65      0       1
# 3     31    59      2       1
# 4     31    65      4       1
# 5     33    58     10       1
# 6     33    60      0       1
# 9     34    58     30       1
# 10    34    60      1       1
# 11    34    61     10       1
# 12    34    67      7       1
# 13    34    60      0       1
# 14    35    64     13       1
# 15    35    63      0       1
# 16    36    60      1       1
# 17    36    69      0       1
# 18    37    60      0       1
# 19    37    63      0       1
# 20    37    58      0       1
# 21    37    59      6       1
# 22    37    60     15       1
# 23    37    63      0       1
# 25    38    59      2       1
# 26    38    60      0       1
# 27    38    60      0       1
# 28    38    62      3       1
# 29    38    64      1       1
# 30    38    66      0       1
# 31    38    66     11       1
# 32    38    60      1       1
# ..   ...   ...    ...     ...
# 265   65    59      2       1
# 266   65    64      0       1
# 267   65    67      1       1
# 270   66    58      0       1
# 271   66    58      1       1
# 272   66    68      0       1
# 275   67    66      0       1
# 276   67    66      0       1
# 277   67    61      0       1
# 278   67    65      0       1
# 279   68    67      0       1
# 280   68    68      0       1
# 282   69    60      0       1
# 283   69    65      0       1
# 284   69    66      0       1
# 287   70    66     14       1
# 288   70    67      0       1
# 289   70    68      0       1
# 290   70    59      8       1
# 291   70    63      0       1
# 292   71    68      2       1
# 294   72    58      0       1
# 295   72    64      0       1
# 296   72    67      3       1
# 297   73    62      0       1
# 298   73    68      0       1
# 300   74    63      0       1
# 301   75    62      1       1
# 302   76    67      0       1
# 303   77    65      3       1
#
# [225 rows x 4 columns]
#      age  year  nodes  status
# 7     34    59      0       2
# 8     34    66      9       2
# 24    38    69     21       2
# 34    39    66      0       2
# 43    41    60     23       2
# 44    41    64      0       2
# 45    41    67      0       2
# 53    42    69      1       2
# 54    42    59      0       2
# 62    43    58     52       2
# 63    43    59      2       2
# 64    43    64      0       2
# 65    43    64      0       2
# 73    44    64      6       2
# 74    44    58      9       2
# 75    44    63     19       2
# 80    45    65      6       2
# 81    45    66      0       2
# 82    45    67      1       2
# 89    46    58      2       2
# 90    46    69      3       2
# 91    46    62      5       2
# 92    46    65     20       2
# 96    47    63     23       2
# 97    47    62      0       2
# 98    47    65      0       2
# 107   48    58     11       2
# 108   48    58     11       2
# 109   48    67      7       2
# 114   49    63      0       2
# ..   ...   ...    ...     ...
# 181   55    68     15       2
# 190   56    65      9       2
# 191   56    66      3       2
# 197   57    61      5       2
# 198   57    62     14       2
# 199   57    64      1       2
# 215   59    62     35       2
# 223   60    59     17       2
# 224   60    65      0       2
# 229   61    62      5       2
# 230   61    65      0       2
# 231   61    68      1       2
# 238   62    59     13       2
# 239   62    58      0       2
# 240   62    65     19       2
# 245   63    60      1       2
# 258   65    58      0       2
# 259   65    61      2       2
# 260   65    62     22       2
# 261   65    66     15       2
# 268   66    58      0       2
# 269   66    61     13       2
# 273   67    64      8       2
# 274   67    63      1       2
# 281   69    67      8       2
# 285   70    58      0       2
# 286   70    58      4       2
# 293   72    63      0       2
# 299   74    65      3       2
# 304   78    65      1       2
#
# [80 rows x 4 columns]

# %% [markdown]
# # univariate analysis (histogram, PDF, CDF)

# %%
sns.FacetGrid(cancer,hue='status',size=6).map(sns.distplot,'age').add_legend()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(cancer,hue='status',size=6).map(sns.distplot,'year').add_legend()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(cancer,hue='status',size=6).map(sns.distplot,'nodes').add_legend()
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # observations
# the above graph is giving some clear picture in differentiating both statuses. In the above two graphs,both are mixed up and we cant clearly understand them.
#
# so,we use nodes column for our analysis

# %%
#probability distribution function of status=1
counts1,bin_edges1=np.histogram(status1['nodes'],bins=10,density = True)
pdf1=counts1/(sum(counts1))
print(pdf1);
print(bin_edges1)

#cumulative distribution function of status=1
cdf1=np.cumsum(pdf1)
plt.plot(bin_edges1[1:],pdf1)
plt.plot(bin_edges1[1:],cdf1)
plt.xlabel('nodes')
plt.show()
# Out:
# [0.83555556 0.08       0.02222222 0.02666667 0.01777778 0.00444444
#  0.00888889 0.         0.         0.00444444]
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]

# %%
#probability distribution function of status=2
counts2,bin_edges2=np.histogram(status2['nodes'], bins=10, density = True)
pdf2=counts2/(sum(counts2))
print(pdf2);
print(bin_edges2)

#cumulative distribution function of status=2
cdf2=np.cumsum(pdf2)
plt.plot(bin_edges1[1:],pdf2)
plt.plot(bin_edges1[1:],cdf2)
plt.xlabel('nodes')
plt.show()
# Out:
# [0.5625 0.15   0.1375 0.05   0.075  0.     0.0125 0.     0.     0.0125]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %% [markdown]
# # observations
#
# 1. people having nodes<1(0 to 0.85) have lived.
#
# 2. people having nodes>0.5 have died

# %%
#finding mean and standard deviation for status=1

print('mean of the nodes of the people who survived:',np.mean(status1['nodes']))    #we came to know that the average nodes of people who survived for morethan 5 years after operation is 2.7. 


print('outlier mean:',np.mean(np.append(status1['nodes'],50)))      #mean has a problem with outlier values

#finding mean and standard deviation for status=2

print('mean of the nodes of the people who died:',np.mean(status2['nodes']))    #we came to know that the average nodes of people who died within 5 years after operation is 7.525.
# Out:
# mean of the nodes of the people who survived: 2.7911111111111113
# outlier mean: 3.0
# mean of the nodes of the people who died: 7.525

# %%
# if somebody mistakenly entered 50 as no.of nodes,the mean value changes from 2.7 to 3. 
#this may cuase problems if more ouliers like this appears in our data

# %%
print(np.std(status1['nodes']))       #people with <=6 nodes have chances to live
print(np.std(status2['nodes']))       #people with >=9 nodes may die
# Out:
# 5.857258449412131
# 9.165117293302908

# %% [markdown]
# # observations
# As we know that mean and standard deviation has a problem with outliers. if we add some outlier value(value which is very larger than actual mean),the mean value changes.but this mean value is wrong.
#
# so,we have to go with median to take average age of people in both categories

# %%
#median

print('median of the no. of nodes of people %who survived:',np.median(status1['nodes']))    # people with avg. 0 nodes will live

print('median of the no. of nodes of people who died:',np.median(status2['nodes']))         # people with avg. 4 nodes will die
# Out:
# median of the no. of nodes of people %who survived: 0.0
# median of the no. of nodes of people who died: 4.0

# %%
print(np.std(status1['nodes']))    # 5+-0 nodes -> live  (5 nodes)
print(np.std(status2['nodes']))    # 9+-4 nodes -> die   (5-13 nodes)
# Out:
# 5.857258449412131
# 9.165117293302908

# %%
#quantiles
print(np.percentile(status1['nodes'],np.arange(0,100,25)))       

print(np.percentile(status2['nodes'],np.arange(0,100,25)))
# Out:
# [0. 0. 0. 3.]
# [ 0.    1.    4.   11.25]

# %%
#90th quantile

print(np.percentile(status1['nodes'],90))           # 90% chances for 8 people may live 
print(np.percentile(status2['nodes'],90))           # 90% chances for 20 people may die
# Out:
# 8.0
# 20.10000000000001

# %%
from statsmodels import robust
print('median absolute deviation:')
print('status1:',robust.mad(status1['nodes']))
print('status2:',robust.mad(status2['nodes']))
# Out:
# median absolute deviation:
# status1: 0.0
# status2: 5.930408874022408

# %% [markdown]
# # box plot and violin plots

# %%
x,y='status','nodes'
bp=sns.boxplot(x,y,data=cancer)
print(bp)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # observations
# 1. people with nodes<=2(approx.) have chances to live.
#
# 2. people with nodes>=1 (approx.) may die

# %%
vp=sns.violinplot(x,y,data=cancer)
print(vp)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.jointplot(x,y,data=cancer,kind="kde");
plt.show();

# %% [markdown]
# # observations
# 1. people with nodes in range 0.9 to 1 have chances to live.
#
# 2. people with nodes in range 2 may die

# %% [markdown]
# # Final Conclusions
#
# 1. Nodes attribute plays key role in this analysis
# 2. we used Node varible in our univariate analysis to find the number of nodes needed to live or die.
# 3. After finding median,mad we got:
#             i)5 nodes to live
#             ii) 9-13 nodes may die
# 4. people with more nodes(>5) have more chances to die.
# 5. people with less nodes(<2) have more chances to live.
# 6. we can use age also for our analysis. age is also giving same result(in terms of age needed to live or die)
#
# # sample code
#
# if(nodes<=0): print('live')
#
# elif(nodes>0 and nodes<=5): print('may live')
#
# elif(nodes>=5 && nodes<=9): print('may die')
#
# else: print('die')
